# %%
import pandas as pd

# %%
excel_path = 'Day 1 list1-5 - 副本.xlsx'
all_words = pd.read_excel(excel_path)
all_words.head(10)
# all_words.iloc[0,1]
# all_words.sort_values(by=['Unnamed: 0'], axis=0, ascending=False)
# Out:
#    Unnamed: 0      word                      Unnamed: 2  Unnamed: 3
# 0         3.0     abase            v.贬低，使谦卑（降低地位、威望或尊严）    0.725378
# 1         3.0   bespeak             v. 显示；流露；展现；预言；\n预示    0.092685
# 2         3.0   besiege       v. 烦扰；纠缠；使感到丧气\n或焦虑；包围；围攻    0.278013
# 3         3.0     beset                 v. 困扰；烦扰；使苦恼；围攻    0.779295
# 4         3.0   beseech                      v.恳求；央求；哀求    0.523237
# 5         3.0    bereft  adj. 失去...的；缺少的 (某些需\n要或希望的东西)    0.755069
# 6         3.0    berate            v.  (愤怒并长时间地)  批评或指责    0.256742
# 7         3.0   bequest                        n. 遗赠，遗产    0.557363
# 8         3.0  bequeath                      v. 遗留给，传下去    0.666068
# 9         2.0      bent       n. 倾向，爱好; 才能；天赋\nadj. 决心的    0.443795

# %%
all_words.iloc[0,0]+=1

# %%
all_words.head()
# Out:
#    Unnamed: 0  \
# 0         2.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#
#   使用说明：1.一手按在数字上，一手按在↓上。单词不知道意思就按1（第二次不会按2），一遍过后按Ctrl+A全选，然后点最上面的数据——〉排序——〉按A列排就好了。D列已经做好了随机数字，按D列排序可得乱序词汇表~2.如果想盖住解释只看单词，把行宽拉大到看不到汉语意思即可。想看汉语意思只需要按→就可以惹~~~祝大家杀鸡成功(＾－＾)V更多免费完整版本资料请加上校微信：vcalive1203。  \
# 0                                              abase
# 1                                              abate
# 2                                         abbreviate
# 3                                           abdicate
# 4                                         aberration
#
#                Unnamed: 2  Unnamed: 3
# 0    v.贬低，使谦卑（降低地位、威望或尊严）    0.725378
# 1                 v.减少，降低    0.142700
# 2                 v.缩写，缩短    0.886323
# 3  v.退位；辞职\nv.放弃（责任）；失（职）    0.752158
# 4            n.偏离正常，非典型行为    0.301580

# %%
excel_path = 'Day 1 list1-5 - 副本.xlsx'
all_words.to_excel(excel_path, index=False)

# %%
def a():
    a = all_words.sort_values(by=['Unnamed: 0'], axis=0, ascending=False)
    return a

# %%
class WordReader(object):
    
    def __init__(self, excel_path, is_random=False):
        self.excel_path = excel_path
        self.all_words = pd.read_excel(self.excel_path)
        self.words_sorted = self.all_words.sort_values(by=['Unnamed: 0'], axis=0, ascending=False)
        self.is_random = is_random
        self.len = len(self.all_words)            
        
    def memorize(self, word_num):
        if word_num > self.len:
            word_num = self.len
        for i in range(word_num - 1):
            word = self.words_sorted.iloc[i,1]
            mean = self.words_sorted.iloc[i,2]
            flag = input(str(i) +':  '+ word)
            if flag == 'yes':
                print(mean)
                continue
            elif flag == '':
                print(mean)
                self.words_sorted.iloc[i,0] += 1
                
    def sorting(self, top=100):
        sorted_ver = self.words_sorted.sort_values(by=['Unnamed: 0'], axis=0, ascending=False)
        return sorted_ver.iloc[:top,:]
    
    def update_excel(self):
        sorted_ver = self.words_sorted.sort_values(by=['Unnamed: 0'], axis=0, ascending=False)
        sorted_ver.to_excel(self.excel_path, index=False)
        print('Excel update done!')

# %%
day1 = WordReader('Day 1 list1-5 - 副本.xlsx')

# %%
day1.memorize(300)
# Out:
# 0abase
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     883             try:
# --> 884                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     885             except Exception:
#
# ~\anaconda3\lib\site-packages\jupyter_client\session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~\anaconda3\lib\site-packages\zmq\sugar\socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~\anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-afc4f3dddeaa> in <module>
# ----> 1 day1.memorize(300)
#
# <ipython-input-4-f177be051959> in memorize(self, word_num)
#      14             word = self.words_sorted.iloc[i,1]
#      15             mean = self.words_sorted.iloc[i,2]
# ---> 16             flag = input(str(i) + word)
#      17             if flag == 'yes':
#      18                 print(mean)
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     857             self._parent_ident,
#     858             self._parent_header,
# --> 859             password=False,
#     860         )
#     861
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     887             except KeyboardInterrupt:
#     888                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 889                 raise KeyboardInterrupt
#     890             else:
#     891                 break
#
# KeyboardInterrupt:

# %%
day1.sorting()
# Out:
#      Unnamed: 0        word                             Unnamed: 2  Unnamed: 3
# 0           3.0       abase                   v.贬低，使谦卑（降低地位、威望或尊严）    0.725378
# 449         3.0   cauterize  v.  使麻木不仁；使变得无\n情；烙，烧灼(伤口；目的\n是消毒或止血)    0.135109
# 367         3.0      brazen      adj. 厚颜无耻的，肆无忌惮\n的\nv. 大胆自信地去面对或从    0.756586
# 366         3.0     bravura         adj. （表演或作品）精彩的，\n华丽的\nn. 精湛技艺    0.060652
# 365         3.0     bravado               n. 虚张声势，故作勇敢，逞能; 假装表现出勇敢    0.128900
# ..          ...         ...                                    ...         ...
# 28          3.0      accede                         v. 答应，同意；就任；就职    0.644499
# 27          3.0     abysmal                 adj. 极坏的；糟透的；深重\n的；无边的    0.435274
# 150         3.0    aphorism                                n.格言；警语    0.603196
# 152         3.0  apocryphal                         adj. 假的虚构的，杜撰的    0.252503
# 75          3.0  affiliated                         adj. 相关类似的；隶属的    0.905193
#
# [100 rows x 4 columns]

# %%
day1.update_excel()
# Out:
# Excel update done!
